# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\hp\Desktop\Data a\pandas tut\coal pubic data\coalpublic2013.xls")
df
# Out:
#                   Historical Coal Production Data: 2013 Unnamed: 1  \
# 0     Source: The U.S. Energy Information Administra...        NaN
# 1                                                   NaN        NaN
# 2                                                  Year    MSHA ID
# 3                                                  2013     103381
# 4                                                  2013     103404
# 5                                                  2013     100759
# 6                                                  2013     103246
# 7                                                  2013     103451
# 8                                                  2013     103433
# 9                                                  2013     100329
# 10                                                 2013     100851
# 11                                                 2013     102901
# 12                                                 2013     102901
# ...

# %%
df.columns=df.iloc[2]

# %%
#df.reindex(df.index.drop())
df
# Out:
# 2                                                  Year  MSHA ID  \
# 0     Source: The U.S. Energy Information Administra...      NaN
# 1                                                   NaN      NaN
# 2                                                  Year  MSHA ID
# 3                                                  2013   103381
# 4                                                  2013   103404
# 5                                                  2013   100759
# 6                                                  2013   103246
# 7                                                  2013   103451
# 8                                                  2013   103433
# 9                                                  2013   100329
# 10                                                 2013   100851
# 11                                                 2013   102901
# 12                                                 2013   102901
# ...

# %%
df=df.drop([0,1])
df=df.drop(2)
df
# Out:
# 2     Year  MSHA ID                       Mine Name       Mine State  \
# 3     2013   103381            Tacoa Highwall Miner          Alabama
# 4     2013   103404                Reid School Mine          Alabama
# 5     2013   100759  North River #1 Underground Min          Alabama
# 6     2013   103246                      Bear Creek          Alabama
# 7     2013   103451                     Knight Mine          Alabama
# 8     2013   103433              Crane Central Mine          Alabama
# 9     2013   100329                    Concord Mine          Alabama
# 10    2013   100851                  Oak Grove Mine          Alabama
# 11    2013   102901                Shoal Creek Mine          Alabama
# 12    2013   102901                Shoal Creek Mine          Alabama
# 13    2013   103180             Sloan Mountain Mine          Alabama
# 14    2013   103182                        Fishtrap          Alabama
# 15    2013   103285                     Narley Mine          Alabama
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
# 2     Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# 5     2013   103433              Crane Central Mine          Alabama
# 6     2013   100329                    Concord Mine          Alabama
# 7     2013   100851                  Oak Grove Mine          Alabama
# 8     2013   102901                Shoal Creek Mine          Alabama
# 9     2013   102901                Shoal Creek Mine          Alabama
# 10    2013   103180             Sloan Mountain Mine          Alabama
# 11    2013   103182                        Fishtrap          Alabama
# 12    2013   103285                     Narley Mine          Alabama
# ...

# %%
#df=df.rename(columns={2:''})
print(df.index.name)
# Out:
# None

# %%
df[['MSHA ID','Labor Hours']].groupby(['MSHA ID']).sum()
# Out:
# 2        Labor Hours
# MSHA ID
# 100329        144002
# 100347        215295
# 100515          6240
# 100759        474784
# 100851       1001809
# 101247       1551141
# 101362        116914
# 101401       2464719
# 102901       1249811
# 102976         38021
# 102996        164093
# 103155         79990
# 103172        119542
# 103179         63745
# 103180        196963
# 103182         87314
# 103195         17411
# 103246         29193
# 103285         90584
# 103303        164388
# 103321         76366
# 103323         46381
# 103332         61394
# 103342        115123
# 103358        161805
# 103364         14324
# 103370           621
# 103372         32401
# 103375          1900
# 103376        176499
# ...              ...
# 4609427        75496
# 4609428        39811
# 4609431         2480
# 4609440        13154
# 4609448        69144
# 4609454        29793
# 4609455        21023
# 4609462         9770
# 4609468        30035
# 4609470        30342
# 4609481         2456
# ...

# %%
import re
df.loc[df['Mine Name'].str.contains('^p',flags=re.I,na=False)]
# Out:
# 2     Year  MSHA ID                       Mine Name                Mine State  \
# 13    2013   103332                   Powhatan Mine                   Alabama
# 18    2013   102976   Piney Woods Preparation Plant                   Alabama
# 19    2013   102976   Piney Woods Preparation Plant                   Alabama
# 46    2013   103321                  Poplar Springs                   Alabama
# 50    2013   301569                        Penny #1                  Arkansas
# 73    2013  1103143                   Prairie Eagle                  Illinois
# 74    2013  1103143                   Prairie Eagle                  Illinois
# 75    2013  1103147       Prairie Eagle-Underground                  Illinois
# 76    2013  1103205  Prairie Eagle South Undergroun                  Illinois
# 80    2013  1102546               Preparation Plant                  Illinois
# 94    2013  1103058                         Pattiki                  Illinois
# ...

# %%
df.loc[(df['MSHA ID']==102976) | (df['MSHA ID']==103380)]
# Out:
# 2   Year MSHA ID                      Mine Name Mine State Mine County  \
# 18  2013  102976  Piney Woods Preparation Plant    Alabama      Shelby
# 19  2013  102976  Piney Woods Preparation Plant    Alabama      Shelby
# 20  2013  103380                         Calera    Alabama      Shelby
# 21  2013  103380                         Calera    Alabama      Shelby
#
# 2  Mine Status    Mine Type                  Company Type     Operation Type  \
# 18      Active      Surface  Indepedent Producer Operator  Preparation Plant
# 19      Active  Underground  Indepedent Producer Operator  Preparation Plant
# 20      Active      Surface  Indepedent Producer Operator  Preparation Plant
# 21      Active  Underground  Indepedent Producer Operator  Preparation Plant
#
# 2                Operating Company                Operating Company Address  \
# 18         Jesse Creek Mining, Llc  1615 Kent Dairy Rd, Alabaster, AL 35007
# ...

# %%
import matplotlib.pyplot as plt
sorted_by_production = df.sort_values(['Production (short tons)'], ascending=False).head(10)
sorted_by_production['Production (short tons)'].head(10).plot(kind="barh")
plt.show()

# %%
#sorted_by_production = df.sort_values(['Production (short tons)'], ascending=False).head(10)
df[['Year','MSHA ID','Production (short tons)','Labor Hours']].head(10).plot(kind="bar",figsize=(20,8))
plt.show()
